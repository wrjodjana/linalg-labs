# %%
from sympy import *
import matplotlib.pyplot as plt
init_printing()

# %%
x, y, z, t = symbols('x y z t')
k, m, n = symbols('k m n', integer=True)
f, g, h = symbols('f g h', cls=Function)

# %%
M = Matrix([[-1, 1, -1, 1, -9], 
            [-8, 4, -2, 1, 8],
            [27, 9,  3, 1, -57],
            [8,  4,  2, 1, -12]])
R=M.rref()[0]
print(R)
# Out:
# Matrix([[1, 0, 0, 0, -3], [0, 1, 0, 0, 1], [0, 0, 1, 0, 7], [0, 0, 0, 1, -6]])

# %%
plot(-3*x**3+x**2+7*x-6, line_color="red")

# %%
M = Matrix([[1, 1, 1, 1, 1, 1], 
            [81, -27, 9, -3, 1, 365],
            [16, -8, 4, -2, 1, 112],
            [81, 27, 9, 3,1, 47],
            [256, 64, 16, 4, 1, 232]])
R=M.rref()[0]
print(R)
# Out:
# Matrix([[1, 0, 0, 0, 0, 2], [0, 1, 0, 0, 0, -5], [0, 0, 1, 0, 0, 4], [0, 0, 0, 1, 0, -8], [0, 0, 0, 0, 1, 8]])

# %%
plot(2*x**4-5*x**3+4*x**2-8*x+8, line_color="red")

# %%
M = Matrix([[1, 1, 1, 1, 1, 1, -1], 
            [-32, 16, -8, 4, -2, 1, 221],
            [32, 16, 8, 4, 2, 1, -27],
            [-243, 81, -27, 9, -3, 1, 1343],
            [243, 81, 27, 9, 3,1, -349 ],
            [-1, 1, -1, 1, -1, 1, 3]])
R=M.rref()[0]
print(R)
# Out:
# Matrix([[1, 0, 0, 0, 0, 0, -3], [0, 1, 0, 0, 0, 0, 6], [0, 0, 1, 0, 0, 0, -5], [0, 0, 0, 1, 0, 0, 2], [0, 0, 0, 0, 1, 0, 6], [0, 0, 0, 0, 0, 1, -7]])

# %%
plot(-3*x**5+6*x**4-5*x**3+2*x**2+6*x-7, line_color="red")

# %%
M = Matrix([[0, 0, 0, 0, 0, 1, 122.32],
            [1, 1, 1, 1, 1, 1, 139.29],
            [32, 16, 8, 4, 2, 1, 172.38 ],
            [243, 81, 27, 9, 3, 1, 296.65],
            [1024, 256, 64, 16, 4, 1, 472],
            [3125, 625, 125, 25, 5, 1, 680.11] 
            ])
R=M.rref()[0]
print(R)
# Out:
# Matrix([[1, 0, 0, 0, 0, 0, 1.14116666666656], [0, 1, 0, 0, 0, 0, -16.2099999999986], [0, 0, 1, 0, 0, 0, 81.2408333333270], [0, 0, 0, 1, 0, 0, -139.309999999989], [0, 0, 0, 0, 1, 0, 90.1079999999943], [0, 0, 0, 0, 0, 1, 122.320000000000]])

# %%
plot(1.14116666666656*x**5-16.2099999999986*x**4+81.2408333333270*x**3-139.309999999989*x**2+90.1079999999943*x+122.320000000000, line_color="red")
